# %% [markdown]
# ## **Waste classification**
#
# The project concerns waste classification to determine if it may be recycle or not. The dataset contains waste images  recyclable and organic ones. We will try to train a model that will be able to  recognise them all.
# It is a binary classification problem and we will train the model in TensorFlow.
#
# **Data**
#
# The dataset contains images divided into two classes: organic waste and recycle waste and it is split into train data (85%) and test data (15%).
# Training dataset contains 22564 images while test dataset 2513 images.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import PIL

import keras
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Activation
from keras.layers import Dropout, Dense, Flatten, BatchNormalization

# %%
cd '/content/drive/My Drive/Kaggle'
# Out:
# /content/drive/My Drive/Kaggle

# %% [markdown]
# ### **Data preparation**

# %%
train_dir = '/content/drive/My Drive/Kaggle/DATASET/TRAIN'
test_dir = '/content/drive/My Drive/Kaggle/DATASET/TEST'

# %% [markdown]
# We load images with **image_dataset_from_directory** - this method returns an object **tf.data.Dataset**.
#
# We define some of parameters:

# %%
batch_size = 32
img_height = 64
img_width = 64

# %% [markdown]
# Create a dataset:

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset='training',
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 22564 files belonging to 2 classes.
# Using 18052 files for training.

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  test_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2513 files belonging to 2 classes.
# Using 502 files for validation.

# %% [markdown]
# The class names can be found in the attribute class_names. They correspond to directory names in alphabetical order.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['O', 'R']

# %% [markdown]
#  **Data visualization**
#
# Here there are first 9 images from the training dataset.

# %%
plt.figure(figsize= (10,10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype('uint8'))
    plt.title(class_names[labels[i]])
    plt.axis('off')

# %% [markdown]
# Shape of data:

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 64, 64, 3)
# (32,)

# %% [markdown]
# **Data standardization**
#
# The RGB channel values fall into the [0, 255] range. We have to standardize values to be in the [0, 1] range. We use a Rescaling layer for it.

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
X_train, y_train = next(iter(normalized_ds))
first_image = X_train[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
normalized_test = test_ds.map(lambda x, y: (normalization_layer(x), y))
X_test, y_test = next(iter(normalized_test))
first_img = X_test[0]
print(np.min(first_img), np.max(first_img))
# Out:
# 0.0 1.0

# %% [markdown]
# ### **Creating the model**
#
# We build model with Convolutional Neural Network (CNN) and we will test a few models.
#
# The model consists of three convolution blocks with a max pool layer in each of them. There's a fully connected layer with three Dense layers. First two layers are activated by a relu activation function and the last is activated by a sigmoid activation function.
#
# Compile the model:
#
# We choose the Adam optimizer and the loss function: binary_crossentropy. To view training and validation accuracy for each training epoch, we use metrics "accuracy".

# %%
model = Sequential([                
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(64, 64, 3)), 
  tf.keras.layers.MaxPool2D((2,2)),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
  tf.keras.layers.MaxPool2D((2,2)),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
  tf.keras.layers.MaxPool2D((2,2)),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(units=128, activation="relu"),
  tf.keras.layers.Dense(units=64, activation="relu"),
  tf.keras.layers.Dense(units=1, activation="sigmoid")
])

model.compile(optimizer = 'adam', loss = 'binary_crossentropy',
                   metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               524416
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 561,377
# Trainable params: 561,377
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Train the model**
#
# We train the model for 30 epoch.

# %%
history = model.fit(
    X_train, y_train,
    epochs = 30,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/30
# 1/1 [==============================] - 7s 7s/step - loss: 0.6684 - accuracy: 0.7188 - val_loss: 1.5038 - val_accuracy: 0.3438
# Epoch 2/30
# 1/1 [==============================] - 0s 34ms/step - loss: 0.7684 - accuracy: 0.7188 - val_loss: 0.9546 - val_accuracy: 0.3438
# Epoch 3/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6219 - accuracy: 0.7188 - val_loss: 0.8011 - val_accuracy: 0.3438
# Epoch 4/30
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6235 - accuracy: 0.7188 - val_loss: 0.7739 - val_accuracy: 0.3438
# Epoch 5/30
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6174 - accuracy: 0.7188 - val_loss: 0.7927 - val_accuracy: 0.3438
# Epoch 6/30
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5931 - accuracy: 0.7188 - val_loss: 0.8655 - val_accuracy: 0.3438
# Epoch 7/30
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5685 - accuracy: 0.7188 - val_loss: 0.9711 - val_accuracy: 0.3438
# Epoch 8/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5579 - accuracy: 0.7188 - val_loss: 1.0031 - val_accuracy: 0.3438
# Epoch 9/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5378 - accuracy: 0.7188 - val_loss: 0.9141 - val_accuracy: 0.3438
# Epoch 10/30
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4983 - accuracy: 0.7188 - val_loss: 0.8133 - val_accuracy: 0.3438
# Epoch 11/30
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4694 - accuracy: 0.7188 - val_loss: 0.7857 - val_accuracy: 0.3438
# Epoch 12/30
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4412 - accuracy: 0.7188 - val_loss: 0.8369 - val_accuracy: 0.4375
# Epoch 13/30
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4024 - accuracy: 0.7812 - val_loss: 0.9354 - val_accuracy: 0.5000
# Epoch 14/30
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3745 - accuracy: 0.8125 - val_loss: 0.9113 - val_accuracy: 0.7188
# Epoch 15/30
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3383 - accuracy: 0.8125 - val_loss: 0.8501 - val_accuracy: 0.7812
# Epoch 16/30
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3178 - accuracy: 0.9062 - val_loss: 0.9788 - val_accuracy: 0.7812
# Epoch 17/30
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2867 - accuracy: 0.9062 - val_loss: 1.2284 - val_accuracy: 0.7500
# Epoch 18/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2697 - accuracy: 0.8438 - val_loss: 1.1800 - val_accuracy: 0.7812
# Epoch 19/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2447 - accuracy: 0.9062 - val_loss: 1.3099 - val_accuracy: 0.7812
# Epoch 20/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2234 - accuracy: 0.9062 - val_loss: 1.6577 - val_accuracy: 0.7500
# Epoch 21/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2114 - accuracy: 0.9062 - val_loss: 1.4045 - val_accuracy: 0.7812
# Epoch 22/30
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1973 - accuracy: 0.9062 - val_loss: 1.7612 - val_accuracy: 0.7812
# Epoch 23/30
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1618 - accuracy: 0.9688 - val_loss: 2.0025 - val_accuracy: 0.7500
# Epoch 24/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1540 - accuracy: 0.9688 - val_loss: 1.6792 - val_accuracy: 0.8125
# Epoch 25/30
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1426 - accuracy: 0.9688 - val_loss: 1.8521 - val_accuracy: 0.8125
# Epoch 26/30
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1213 - accuracy: 0.9688 - val_loss: 2.3151 - val_accuracy: 0.7500
# Epoch 27/30
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1151 - accuracy: 0.9688 - val_loss: 2.3207 - val_accuracy: 0.8125
# Epoch 28/30
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1000 - accuracy: 0.9688 - val_loss: 2.0818 - val_accuracy: 0.8125
# Epoch 29/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0911 - accuracy: 0.9688 - val_loss: 2.0390 - val_accuracy: 0.7812
# Epoch 30/30
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0868 - accuracy: 0.9688 - val_loss: 2.2299 - val_accuracy: 0.7812

# %%
loss, accuracy = model.evaluate(X_train,y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test,y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Training Accuracy: 0.9688
# Testing Accuracy:  0.7812

# %% [markdown]
# **Visualization training results**
#
# The plots of loss and accuracy on the training and validation sets.

# %%
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# From the above plots one can see that difference in accuracy between training and validation set is noticeable. We are dealing with overfitting. The training accuracy is increasing over time, whereas validation accuracy achieved 78% in the training process.
#
# In this case from this dataset is difficult to achieve good accuracy with a CNN created from scratch.

# %% [markdown]
# **Model 2**
#
# In model two we add additional convolution layers and we reduce the complexity of architecture in fully connected layer to have a better accuracy. We also are adding Dropout layer to fight with overfitting in the training process.

# %%
model2 = Sequential([
   tf.keras.layers.Conv2D(32, (3,3), input_shape=(64, 64, 3), activation='relu', padding='same'),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Conv2D(128, (3,3), activation='relu', padding='same'),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Flatten(),
   tf.keras.layers.Dropout(0.2),
   tf.keras.layers.Dense(64, activation="relu"),
   tf.keras.layers.Dropout(0.2),
   tf.keras.layers.Dense(32, activation="relu"),
   tf.keras.layers.Dense(1, activation="sigmoid")
])

model2.compile(optimizer = 'adam', loss = 'binary_crossentropy',
                   metrics = ['accuracy'])

model2.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_46 (Conv2D)           (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d_46 (MaxPooling (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_36 (Dense)             (None, 64)                131136
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_37 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_38 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 235,745
# Trainable params: 235,745
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_2 = model2.fit(
    X_train, y_train,
    epochs = 30,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/30
# 1/1 [==============================] - 1s 607ms/step - loss: 0.6905 - accuracy: 0.5312 - val_loss: 0.8044 - val_accuracy: 0.3438
# Epoch 2/30
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6334 - accuracy: 0.7188 - val_loss: 0.9829 - val_accuracy: 0.3438
# Epoch 3/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6195 - accuracy: 0.7188 - val_loss: 1.0635 - val_accuracy: 0.3438
# Epoch 4/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5803 - accuracy: 0.7188 - val_loss: 1.0169 - val_accuracy: 0.3438
# Epoch 5/30
# 1/1 [==============================] - 0s 32ms/step - loss: 0.5943 - accuracy: 0.7188 - val_loss: 0.9060 - val_accuracy: 0.3438
# Epoch 6/30
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5693 - accuracy: 0.7188 - val_loss: 0.8350 - val_accuracy: 0.3438
# Epoch 7/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5320 - accuracy: 0.7188 - val_loss: 0.8359 - val_accuracy: 0.3438
# Epoch 8/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5120 - accuracy: 0.7188 - val_loss: 0.8901 - val_accuracy: 0.3438
# Epoch 9/30
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4609 - accuracy: 0.7188 - val_loss: 0.8846 - val_accuracy: 0.3750
# Epoch 10/30
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4218 - accuracy: 0.7188 - val_loss: 0.8734 - val_accuracy: 0.6562
# Epoch 11/30
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3748 - accuracy: 0.7812 - val_loss: 0.9347 - val_accuracy: 0.7188
# Epoch 12/30
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3462 - accuracy: 0.8125 - val_loss: 1.0328 - val_accuracy: 0.7500
# Epoch 13/30
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3066 - accuracy: 0.8750 - val_loss: 1.4016 - val_accuracy: 0.7188
# Epoch 14/30
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2849 - accuracy: 0.8125 - val_loss: 1.0979 - val_accuracy: 0.7812
# Epoch 15/30
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2624 - accuracy: 0.8750 - val_loss: 1.3363 - val_accuracy: 0.7500
# Epoch 16/30
# 1/1 [==============================] - 0s 131ms/step - loss: 0.3043 - accuracy: 0.7812 - val_loss: 1.8856 - val_accuracy: 0.7188
# Epoch 17/30
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2607 - accuracy: 0.8438 - val_loss: 1.8215 - val_accuracy: 0.7188
# Epoch 18/30
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2544 - accuracy: 0.9375 - val_loss: 1.5170 - val_accuracy: 0.8125
# Epoch 19/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2631 - accuracy: 0.8438 - val_loss: 1.6224 - val_accuracy: 0.8125
# Epoch 20/30
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1973 - accuracy: 0.8750 - val_loss: 2.1004 - val_accuracy: 0.7188
# Epoch 21/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2484 - accuracy: 0.8438 - val_loss: 2.2116 - val_accuracy: 0.7188
# Epoch 22/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2318 - accuracy: 0.9062 - val_loss: 2.0291 - val_accuracy: 0.8125
# Epoch 23/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1480 - accuracy: 0.9688 - val_loss: 1.9919 - val_accuracy: 0.8125
# Epoch 24/30
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1731 - accuracy: 0.9375 - val_loss: 2.1341 - val_accuracy: 0.8125
# Epoch 25/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1511 - accuracy: 0.9688 - val_loss: 2.3598 - val_accuracy: 0.8125
# Epoch 26/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1353 - accuracy: 0.9688 - val_loss: 2.6066 - val_accuracy: 0.7812
# Epoch 27/30
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1534 - accuracy: 0.9375 - val_loss: 2.6173 - val_accuracy: 0.8125
# Epoch 28/30
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1071 - accuracy: 0.9688 - val_loss: 2.4390 - val_accuracy: 0.8125
# Epoch 29/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1553 - accuracy: 0.9375 - val_loss: 2.3033 - val_accuracy: 0.8125
# Epoch 30/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1034 - accuracy: 0.9688 - val_loss: 2.3308 - val_accuracy: 0.8125

# %%
loss, accuracy = model2.evaluate(X_train,y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model2.evaluate(X_test,y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Training Accuracy: 0.9688
# Testing Accuracy:  0.8125

# %%
plot_graphs(history_2, "accuracy")
plot_graphs(history_2, "loss")

# %% [markdown]
# The validation accuracy is achieved 81% in the training process.
#
# The training accuracy is increasing over time, whereas validation accuracy stalls around 80% in the training process. We also see that the overfitting slightly decreased. The validation loss reaches a minimum value after 5 epochs, and then stabilizes, with the training loss decreasing linearly until the values are close to 0.

# %% [markdown]
# **Model 3**
#
# We also may add Batch Normalization to reduce overfitting.

# %%
model3 = Sequential([
   tf.keras.layers.Conv2D(32, (3,3), input_shape=(64, 64, 3), activation='relu', padding='same'),
   tf.keras.layers.BatchNormalization(),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
   tf.keras.layers.BatchNormalization(),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
   tf.keras.layers.BatchNormalization(),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Conv2D(128, (3,3), activation='relu', padding='same'),
   tf.keras.layers.BatchNormalization(),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Flatten(),
   tf.keras.layers.Dropout(0.2),
   tf.keras.layers.Dense(64, activation="relu"),
   tf.keras.layers.Dense(32, activation="relu"),
   tf.keras.layers.Dense(1, activation="sigmoid")
])

model3.compile(optimizer='adam', loss = 'binary_crossentropy',
                   metrics = ['accuracy'])

model3.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_39 (Conv2D)           (None, 64, 64, 32)        896
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 64, 64, 32)        128
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_30 (Dense)             (None, 64)                131136
# _________________________________________________________________
# dense_31 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 236,769
# Trainable params: 236,257
# Non-trainable params: 512
# _________________________________________________________________

# %% [markdown]
# In this case we train the model for 40 epoch.

# %%
history_3 = model3.fit(
    X_train, y_train,
    epochs = 40,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/40
# 1/1 [==============================] - 1s 779ms/step - loss: 2.1899 - accuracy: 0.3125 - val_loss: 0.7416 - val_accuracy: 0.3438
# Epoch 2/40
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6517 - accuracy: 0.7188 - val_loss: 0.7296 - val_accuracy: 0.3438
# Epoch 3/40
# 1/1 [==============================] - 0s 164ms/step - loss: 0.2620 - accuracy: 0.8750 - val_loss: 0.7169 - val_accuracy: 0.3438
# Epoch 4/40
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1507 - accuracy: 0.9688 - val_loss: 0.7059 - val_accuracy: 0.3438
# Epoch 5/40
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1298 - accuracy: 0.9688 - val_loss: 0.7012 - val_accuracy: 0.2500
# Epoch 6/40
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0816 - accuracy: 1.0000 - val_loss: 0.6997 - val_accuracy: 0.2500
# Epoch 7/40
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0964 - accuracy: 1.0000 - val_loss: 0.7018 - val_accuracy: 0.3125
# Epoch 8/40
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0524 - accuracy: 1.0000 - val_loss: 0.7045 - val_accuracy: 0.3750
# Epoch 9/40
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0324 - accuracy: 1.0000 - val_loss: 0.7079 - val_accuracy: 0.3750
# Epoch 10/40
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.7109 - val_accuracy: 0.3750
# Epoch 11/40
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.7137 - val_accuracy: 0.3438
# Epoch 12/40
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.7145 - val_accuracy: 0.3750
# Epoch 13/40
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.7122 - val_accuracy: 0.3750
# Epoch 14/40
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.7073 - val_accuracy: 0.4062
# Epoch 15/40
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.7019 - val_accuracy: 0.4688
# Epoch 16/40
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.6941 - val_accuracy: 0.5312
# Epoch 17/40
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.6838 - val_accuracy: 0.4688
# Epoch 18/40
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.6743 - val_accuracy: 0.5625
# Epoch 19/40
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.6668 - val_accuracy: 0.6250
# Epoch 20/40
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6614 - val_accuracy: 0.6250
# Epoch 21/40
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6591 - val_accuracy: 0.6250
# Epoch 22/40
# 1/1 [==============================] - 0s 34ms/step - loss: 9.1732e-04 - accuracy: 1.0000 - val_loss: 0.6594 - val_accuracy: 0.6562
# Epoch 23/40
# 1/1 [==============================] - 0s 32ms/step - loss: 9.2875e-04 - accuracy: 1.0000 - val_loss: 0.6622 - val_accuracy: 0.6562
# Epoch 24/40
# 1/1 [==============================] - 0s 35ms/step - loss: 9.7641e-04 - accuracy: 1.0000 - val_loss: 0.6676 - val_accuracy: 0.6562
# Epoch 25/40
# 1/1 [==============================] - 0s 36ms/step - loss: 5.2977e-04 - accuracy: 1.0000 - val_loss: 0.6760 - val_accuracy: 0.6562
# Epoch 26/40
# 1/1 [==============================] - 0s 39ms/step - loss: 5.9410e-04 - accuracy: 1.0000 - val_loss: 0.6870 - val_accuracy: 0.6562
# Epoch 27/40
# 1/1 [==============================] - 0s 36ms/step - loss: 5.3776e-04 - accuracy: 1.0000 - val_loss: 0.7005 - val_accuracy: 0.6562
# Epoch 28/40
# 1/1 [==============================] - 0s 34ms/step - loss: 4.1230e-04 - accuracy: 1.0000 - val_loss: 0.7159 - val_accuracy: 0.6562
# Epoch 29/40
# 1/1 [==============================] - 0s 33ms/step - loss: 4.2612e-04 - accuracy: 1.0000 - val_loss: 0.7330 - val_accuracy: 0.6562
# Epoch 30/40
# 1/1 [==============================] - 0s 33ms/step - loss: 4.6506e-04 - accuracy: 1.0000 - val_loss: 0.7513 - val_accuracy: 0.6562
# Epoch 31/40
# 1/1 [==============================] - 0s 34ms/step - loss: 3.9603e-04 - accuracy: 1.0000 - val_loss: 0.7707 - val_accuracy: 0.6562
# Epoch 32/40
# 1/1 [==============================] - 0s 32ms/step - loss: 2.6945e-04 - accuracy: 1.0000 - val_loss: 0.7907 - val_accuracy: 0.6562
# Epoch 33/40
# 1/1 [==============================] - 0s 35ms/step - loss: 4.1345e-04 - accuracy: 1.0000 - val_loss: 0.8117 - val_accuracy: 0.6562
# Epoch 34/40
# 1/1 [==============================] - 0s 33ms/step - loss: 4.9158e-04 - accuracy: 1.0000 - val_loss: 0.8330 - val_accuracy: 0.6562
# Epoch 35/40
# 1/1 [==============================] - 0s 34ms/step - loss: 3.1789e-04 - accuracy: 1.0000 - val_loss: 0.8545 - val_accuracy: 0.6562
# Epoch 36/40
# 1/1 [==============================] - 0s 32ms/step - loss: 2.4773e-04 - accuracy: 1.0000 - val_loss: 0.8764 - val_accuracy: 0.6562
# Epoch 37/40
# 1/1 [==============================] - 0s 33ms/step - loss: 2.0973e-04 - accuracy: 1.0000 - val_loss: 0.8983 - val_accuracy: 0.6562
# Epoch 38/40
# 1/1 [==============================] - 0s 34ms/step - loss: 2.4952e-04 - accuracy: 1.0000 - val_loss: 0.9200 - val_accuracy: 0.6562
# Epoch 39/40
# 1/1 [==============================] - 0s 36ms/step - loss: 2.4062e-04 - accuracy: 1.0000 - val_loss: 0.9416 - val_accuracy: 0.6562
# Epoch 40/40
# 1/1 [==============================] - 0s 36ms/step - loss: 1.9754e-04 - accuracy: 1.0000 - val_loss: 0.9631 - val_accuracy: 0.6562

# %%
loss, accuracy = model3.evaluate(X_test,y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Testing Accuracy:  0.6562

# %%
plot_graphs(history_3, "accuracy")
plot_graphs(history_3, "loss")

# %% [markdown]
# In this case we achaived the worst validation accuracy equal to 65% in the training process. We see that the training accuracy is increasing over time, whereas validation accuracy stalls around 65% in the training process. Unfortunately the overfitting has grown significantly.
